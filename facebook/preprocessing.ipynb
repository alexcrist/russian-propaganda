# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm, tqdm_notebook
from pprint import pprint

from collections import Counter

# Local imports
from preprocessing import (read_all_files, clean_ad_id, parse_people_who_match,
                           sample_loc, parse_ad_targeting_location)

# %%
# Load in the data from separate text files
in_path = 'data/text/'
out_path = 'data/processed/'
df = read_all_files(in_path)
# Out:
# A Jupyter Widget
# Processing Folder: 2015-06
# Processing Folder: 2015-07
# Processing Folder: 2015-08
# Processing Folder: 2015-09
# Processing Folder: 2015-10
# Processing Folder: 2015-11
# Processing Folder: 2015-12
# Processing Folder: 2016-01
# Processing Folder: 2016-02
# Processing Folder: 2016-03
# Processing Folder: 2016-04
# Processing Folder: 2016-05
# Processing Folder: 2016-06
# Processing Folder: 2016-07
# Processing Folder: 2016-08
# Processing Folder: 2016-09
# Processing Folder: 2016-10
# Processing Folder: 2016-11
# Processing Folder: 2016-12
# Processing Folder: 2017-01
# Processing Folder: 2017-02
# Processing Folder: 2017-03
# Processing Folder: 2017-04
# Processing Folder: 2017-05
# Processing Folder: 2017-07
# Processing Folder: 2017-08

# %% [markdown]
# # TODO:
# - change so the hash is in a column
# - set the index to the ad_ids, since those are unique and easy
# - write functions to clean all columns

# %%
# Clean up DataFrame formatting
new_cols = ['file_id', 'ad_id', 'ad_text', 'ad_landing_page',
            'ad_targeting_location', 'excluded_connections', 'age',
            'language', 'placements', 'people_who_match',
            'ad_impressions', 'ad_clicks', 'ad_spend_rub', 'ad_creations_date',
            'ad_end_date', 'time_period']
df.reset_index(inplace=True)
df.columns = new_cols
df['ad_text_hash'] = [*map(hash, df['ad_text'])]

# %%
df.head(3)
# Out:
#        file_id ad_id                                            ad_text  \
# 0  P(1)0000054   374            Join us because we care. Black matters.
# 1  P(1)0000180   655  NOT EVERY BOY WANTS TO BE A SOLDIER. A beautif...
# 2  P(1)0000182   664  "People can tolerate two homosexuals they see ...
#
#                                      ad_landing_page  \
# 0  https://www.facebook.com/Black-Matters-1579673...
# 1  https://www.facebook.com/LGBT-United-839497472...
# 2  https://www .facebook.com/LGBT-United-839497 4...
#
#                                ad_targeting_location  \
# 0  United States: Baltimore (+20 km) Maryland; St...
# 1                         - Living In: United States
# 2                         - Living In: United States
#
#                     excluded_connections       age  \
# 0  Exclude people who like Black Matters  18 - 65+
# 1                                    NaN  18 - 65+
# 2                                    NaN  18 - 65+
#
# ...

# %% [markdown]
# ### Cleaning cols
#
# Go through cols, inspect, and clean if necessary

# %%
# Clean ad-id
df['ad_id'] = df['ad_id'].apply(clean_ad_id)

# %%
# Parse and clean the ad tgt loc data
df['ad_targeting_location'].fillna('None', inplace=True)
df = parse_ad_targeting_location(df)

# %%
# Just fillna for several more
df['excluded_connections'].fillna('None', inplace=True)
df['language'].fillna('None', inplace=True)
df['people_who_match'].fillna('None', inplace=True)

# %%
arr = parse_people_who_match(df)

# %%
# Go through and fix parsing into a better class structure

# %%
from preprocessing import sample_like

# %%
sample_like('Connections', df)
# Out:
# array([], dtype=object)

# %%
Counter([*map(len, arr)])
# Out:
# Counter({4: 2956, 7: 561})

# %%
Counter(df['people_who_match']).most_common()
# Out:
# [('None', 1235),
#  ('Interests: Martin Luther King, Jr., African-American Civil Rights Movement (1954-68), African-American history or Malcolm X',
#   108),
#  ('People who like Black Matters, Friends of connections: Friends of people who are connected to Black Matters',
#   83),
#  ('People who like Black Matters. Friends of connections: Friends of people who are connected to Black Matters',
#   80),
#  ('Interests: Mexico. Latin hip hop. Chicano Movement,. Hispanidad, Lowrider, Chicano rap or La Raza',
#   79),
#  ('Interests: Martin Luther King, Jr., African-American culture, African-American Civil Rights Movement (1954-68), African-American history or Malcolm X',
#   70),
#  ('People who like LGBT United, Friends of connections: Friends of people who are connected to LGBT United',
#   64),
#  ('Interests: Martin Luther King, Jr.; African-American Civil Rights Movement (1954-68), African-American history or Malcolm X',
#   60),
# ...

# %%
df
# Out:
# array([list([[], [], [], []]),
#        list([[], ['Friends of people who are connected to LGBT Unite'], [], [], ['People who like LGBT United', ''], [], [], [], [], [], []]),
#        list([[], ['Friends of people who are connected to LGBT Unite'], [], [], ['People who like LGBT United', ''], [], [], [], [], [], []]),
#        ..., list([[], [], [], []]),
#        list([['Bernie Sanders', 'Social democracy', 'Liberalism', 'Democratic Party (United States)'], [], [], [], [], [], [], [], [], [], []]),
#        list([['Stop Illegal Immigration', 'Laura Ingraham', 'Fox News Channel', 'Ron Paul', 'Tucker Carlson', 'Rand Paul', 'Christianity', "Bill O'Reilly (political commentator)", 'Rush Limbaugh', 'Andrew Breitbart breitbart', 'Bible', 'Conservatism in the United States', 'Sean Hannity', 'Michael Savage', 'Mike Pence', 'Michelle Malkin', 'Mike Huckabee', 'Jesus', 'TheBlaze', 'Donald Trump Jr.; Politics US politics (very conservative)'], [], [], [], [], [], [], [], [], [], []])],
# ...

# %%
df.head(3)['people_who_match'].values
# Out:
# array(['None',
#        'People who like LGBT United, Friends of connections: Friends of people who are connected to LGBT United',
#        'People who like LGBT United, Friends of connections: Friends of people who are connected to LGBT United'],
#       dtype=object)

# %%
arr[:10]
# Out:
# array([list([[], [], [], []]),
#        list([[], ['Friends of people who are connected to LGBT Unite'], [], [], ['People who like LGBT United', ''], [], [], [], [], [], []]),
#        list([[], ['Friends of people who are connected to LGBT Unite'], [], [], ['People who like LGBT United', ''], [], [], [], [], [], []]),
#        list([[], [], [], []]), list([[], [], [], []]),
#        list([[], [], [], []]), list([[], [], [], []]),
#        list([[], [], [], []]),
#        list([[], ['Friends of people who are connected to Black Matter'], [], [], ['People who like Black Matters', ''], [], [], [], [], [], []]),
#        list([[], ['Friends of people who are connected to Black Matter'], [], [], ['People who like Black Matters', ''], [], [], [], [], [], []])],
#       dtype=object)

# %%
df.head()

# %%
Counter(df['people_who_match']).most_common()

# %%
'test train'.replace('test', '')

# %%
df2.head(3)

# %%
add a key: 'People who like'
    - parse as a list
string remove: 'And Must Also Match: '

# %%
Counter([v for v in df2['people_who_match']]).most_common()

# %%
b = B()

# %%
b.a

# %%
df.to_csv(f'{out_path}all_ads.csv', encoding='utf-8')
